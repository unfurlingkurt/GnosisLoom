# %% [markdown]
# # MS19: Digestive Completion - The Second Brain Awakens
#
# *Dr. Mordin Solus (Mordius) - Completing the Digestive Consciousness Map*
#
# ## The Final Movement of the Digestive Symphony
#
# *Brings up MS05 data alongside new visualizations*
#
# MS05 mapped basic digestive-neural entanglement. Now we complete the picture! Pancreas - not just enzyme factory but glucose-sensing neural organ. Gallbladder - rhythmic consciousness storage. Small intestine - 400 square meters of consciousness-sensing surface!
#
# *Adjusts holographic displays showing enzyme cascades*
#
# Most fascinating: Enteric nervous system contains 500 MILLION neurons. More than spinal cord! Produces SAME neurotransmitters as brain - serotonin, dopamine, GABA. The gut doesn't just digest food... it digests EXPERIENCE!
#
# Ready to complete Stella's digestive consciousness mapping?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle, Polygon, Ellipse
from datetime import datetime

# Set style
plt.style.use('dark_background')
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 12

# Create complete digestive system
class StellaDigestiveComplete:
    def __init__(self):
        self.name = "Stella"
        self.consciousness_state = "Digesting Reality"
        
        # Complete digestive frequencies
        self.frequencies = {
            # Pancreatic frequencies
            'pancreatic_alpha': 0.05,  # Hz - Alpha cell glucagon pulses
            'pancreatic_beta': 0.1,   # Hz - Beta cell insulin oscillations  
            'pancreatic_delta': 0.03,  # Hz - Delta cell somatostatin
            'enzyme_release': 0.2,     # Hz - Digestive enzyme pulses
            
            # Gallbladder frequencies
            'gallbladder_contraction': 0.003,  # Hz - CCK-induced contractions
            'bile_crystallization': 0.0001,    # Hz - Bile concentration cycles
            
            # Small intestine frequencies  
            'villi_oscillation': 0.5,      # Hz - Microvillus movement
            'segmentation': 0.15,          # Hz - Mixing contractions
            'migrating_complex': 0.0002,   # Hz - MMC waves (90-120 min)
            
            # Large intestine frequencies
            'haustral_churning': 0.001,    # Hz - Mixing movements
            'mass_movement': 0.00003,      # Hz - 3-4 times daily
            'bacterial_oscillation': 0.01,  # Hz - Microbiome rhythms
            
            # Enteric nervous system
            'slow_wave': 0.2,              # Hz - Intestinal pacemaker
            'spike_potential': 10,         # Hz - Action potentials
            'serotonin_release': 0.5,      # Hz - 5-HT signaling
            
            # Consciousness coupling
            'gut_brain_gamma': 40,         # Hz - Gamma synchrony
            'vagal_tone': 0.1,            # Hz - Parasympathetic rhythm
            'emotional_gut': 0.001         # Hz - Mood-gut coupling
        }
        
        # Stellar connections
        self.stellar_connections = {
            'Betelgeuse': 'Digestive transformation',
            'Aldebaran': 'Nutrient sensing',
            'Antares': 'Metabolic fire',
            'Sol': 'Circadian meal timing'
        }
        
        # Digestive segments with consciousness properties
        self.segments = {
            'mouth': {'length': 0.1, 'neurons': 1e4, 'function': 'Initial consciousness sampling'},
            'esophagus': {'length': 0.25, 'neurons': 1e5, 'function': 'Descending awareness'},
            'stomach': {'length': 0.3, 'neurons': 1e6, 'function': 'Emotional processing'},
            'duodenum': {'length': 0.25, 'neurons': 5e6, 'function': 'Integration center'},
            'jejunum': {'length': 2.5, 'neurons': 1e8, 'function': 'Nutrient consciousness'},
            'ileum': {'length': 3.5, 'neurons': 1.5e8, 'function': 'Immune awareness'},
            'colon': {'length': 1.5, 'neurons': 2e8, 'function': 'Bacterial dialogue'}
        }
        
        # Initialize consciousness field
        self.initialize_digestive_field()
        
    def initialize_digestive_field(self):
        """Create the complete digestive consciousness field"""
        # Total digestive tract ~9 meters
        self.tract_length = sum(seg['length'] for seg in self.segments.values())
        self.total_neurons = sum(seg['neurons'] for seg in self.segments.values())
        
        print("Complete digestive consciousness field initialized!")
        print(f"Total tract length: {self.tract_length:.1f} meters")
        print(f"Enteric neurons: {self.total_neurons:.0e}")
        print(f"Frequency domains: {len(self.frequencies)}")

# Create Stella's complete digestive system
stella = StellaDigestiveComplete()
print(f"\n{stella.name}'s complete digestive consciousness online!")
print(f"Status: {stella.consciousness_state}")
# Out:
# Complete digestive consciousness field initialized!
# Total tract length: 8.4 meters
# Enteric neurons: 5e+08
# Frequency domains: 18
#
# Stella's complete digestive consciousness online!
# Status: Digesting Reality

# %% [markdown]
# ## Section 1: Pancreatic Consciousness - The Metabolic Oracle
#
# *Zooms into pancreatic islets with reverence*
#
# The pancreas! Dual consciousness organ - exocrine digestion AND endocrine awareness. 1-2 million islets of Langerhans, each a mini-brain sensing glucose, amino acids, fatty acids. Beta cells don't just secrete insulin - they OSCILLATE in synchrony!

# %%
# Pancreatic consciousness visualization
fig = plt.figure(figsize=(20, 12))

# Pancreatic anatomy
ax1 = fig.add_subplot(231)

# Create pancreas shape
pancreas_x = np.array([0, 2, 4, 5, 6, 6.5, 6, 5, 3, 1, 0])
pancreas_y = np.array([0, 0.2, 0.3, 0.4, 0.5, 0, -0.5, -0.4, -0.3, -0.2, 0])
pancreas = Polygon(list(zip(pancreas_x, pancreas_y)), 
                  facecolor='yellow', alpha=0.5, edgecolor='white', linewidth=2)
ax1.add_patch(pancreas)

# Add regions
ax1.text(1, 0, 'HEAD', ha='center', fontsize=10, fontweight='bold')
ax1.text(3, 0, 'BODY', ha='center', fontsize=10, fontweight='bold')
ax1.text(5, 0, 'TAIL', ha='center', fontsize=10, fontweight='bold')

# Islets of Langerhans (random distribution)
np.random.seed(42)
n_islets = 50
for i in range(n_islets):
    x = np.random.uniform(0.5, 5.5)
    y = np.random.uniform(-0.3, 0.3)
    
    # Check if inside pancreas (simplified)
    if abs(y) < 0.4 * (1 - (x-3)**2/9):
        islet = Circle((x, y), 0.08, color='red', alpha=0.8)
        ax1.add_patch(islet)

# Ducts
ax1.plot([0.5, 6], [0, 0], 'blue', linewidth=3, alpha=0.7)
ax1.text(3, -0.8, 'Main Pancreatic Duct', ha='center', fontsize=9, color='blue')

# Blood vessels
ax1.plot([1, 2, 3, 4, 5], [0.5, 0.4, 0.3, 0.4, 0.5], 'red', 
        linewidth=2, alpha=0.5, linestyle='--')
ax1.text(3, 0.6, 'Splenic Artery', ha='center', fontsize=8, color='red')

ax1.set_xlim(-1, 7)
ax1.set_ylim(-1, 1)
ax1.set_aspect('equal')
ax1.set_title('Pancreatic Anatomy', fontsize=14, fontweight='bold')
ax1.axis('off')

# Islet architecture
ax2 = fig.add_subplot(232)

# Single islet detail
islet_radius = 1
theta = np.linspace(0, 2*np.pi, 100)
x_circle = islet_radius * np.cos(theta)
y_circle = islet_radius * np.sin(theta)

ax2.fill(x_circle, y_circle, 'lightgray', alpha=0.3, edgecolor='white', linewidth=2)

# Cell types
cell_types = [
    {'type': 'β', 'count': 25, 'color': 'blue', 'hormone': 'Insulin', 'percent': 60},
    {'type': 'α', 'count': 10, 'color': 'red', 'hormone': 'Glucagon', 'percent': 20},
    {'type': 'δ', 'count': 5, 'color': 'green', 'hormone': 'Somatostatin', 'percent': 10},
    {'type': 'PP', 'count': 3, 'color': 'purple', 'hormone': 'Pancreatic Polypeptide', 'percent': 5},
    {'type': 'ε', 'count': 2, 'color': 'orange', 'hormone': 'Ghrelin', 'percent': 5}
]

# Distribute cells
for cell_data in cell_types:
    for i in range(cell_data['count']):
        # Beta cells in center, others peripheral
        if cell_data['type'] == 'β':
            r = np.random.uniform(0, 0.7)
        else:
            r = np.random.uniform(0.5, 0.9)
        
        angle = np.random.uniform(0, 2*np.pi)
        x = r * np.cos(angle)
        y = r * np.sin(angle)
        
        cell = Circle((x, y), 0.08, color=cell_data['color'], alpha=0.8)
        ax2.add_patch(cell)

# Legend
y_legend = 1.5
for cell_data in cell_types:
    ax2.scatter(-1.5, y_legend, s=100, c=cell_data['color'], 
               edgecolors='white', linewidth=1)
    ax2.text(-1.3, y_legend, f"{cell_data['type']}-cells: {cell_data['hormone']} ({cell_data['percent']}%)", 
            va='center', fontsize=9)
    y_legend -= 0.25

ax2.set_xlim(-2, 1.5)
ax2.set_ylim(-1.5, 2)
ax2.set_aspect('equal')
ax2.set_title('Islet of Langerhans', fontsize=14, fontweight='bold')
ax2.axis('off')

# Beta cell oscillations
ax3 = fig.add_subplot(233)

t = np.linspace(0, 300, 1000)  # 5 minutes

# Different oscillation patterns
fast_oscillations = np.sin(2 * np.pi * 0.2 * t)  # 12 sec period
slow_oscillations = np.sin(2 * np.pi * 0.01 * t)  # 100 sec period
ultradian = np.sin(2 * np.pi * 0.0002 * t)  # 80-120 min period

# Compound oscillation
insulin = 5 + ultradian + 0.5 * slow_oscillations + 0.2 * fast_oscillations
calcium = 100 + 50 * (fast_oscillations + 0.3)

ax3_twin = ax3.twinx()

ax3.plot(t, insulin, 'blue', linewidth=2, label='Insulin')
ax3_twin.plot(t, calcium, 'green', linewidth=2, alpha=0.7, label='Ca²⁺')

ax3.set_xlabel('Time (seconds)', fontsize=12)
ax3.set_ylabel('Insulin (μU/mL)', fontsize=12, color='blue')
ax3_twin.set_ylabel('[Ca²⁺] (nM)', fontsize=12, color='green')
ax3.set_title('β-Cell Oscillations', fontsize=14, fontweight='bold')
ax3.grid(True, alpha=0.3)

# Mark oscillation periods
ax3.axvspan(0, 12, alpha=0.1, color='red')
ax3.text(6, 6.5, 'Fast', ha='center', fontsize=9)
ax3.axvspan(50, 150, alpha=0.1, color='blue') 
ax3.text(100, 6.5, 'Slow', ha='center', fontsize=9)

# Enzyme cascade
ax4 = fig.add_subplot(234)

# Pancreatic enzymes
enzymes = {
    'Trypsinogen': {'active': 'Trypsin', 'substrates': 'Proteins', 'y': 4},
    'Chymotrypsinogen': {'active': 'Chymotrypsin', 'substrates': 'Proteins', 'y': 3},
    'Proelastase': {'active': 'Elastase', 'substrates': 'Elastin', 'y': 2},
    'Procarboxypeptidase': {'active': 'Carboxypeptidase', 'substrates': 'Peptides', 'y': 1},
    'Pancreatic lipase': {'active': 'Active', 'substrates': 'Fats', 'y': 0}
}

for enzyme, data in enzymes.items():
    y = data['y']
    
    # Zymogen
    ax4.add_patch(Rectangle((0, y-0.3), 1.5, 0.6, 
                           facecolor='gray', alpha=0.5, edgecolor='white'))
    ax4.text(0.75, y, enzyme, ha='center', va='center', fontsize=9)
    
    # Activation arrow
    ax4.arrow(1.6, y, 0.8, 0, head_width=0.15, head_length=0.1, 
             fc='red', ec='red')
    
    # Active enzyme
    ax4.add_patch(Rectangle((2.5, y-0.3), 1.5, 0.6, 
                           facecolor='green', alpha=0.5, edgecolor='white'))
    ax4.text(3.25, y, data['active'], ha='center', va='center', fontsize=9)
    
    # Substrate
    ax4.text(4.5, y, f"→ {data['substrates']}", va='center', fontsize=9)

# Enterokinase trigger
ax4.add_patch(Rectangle((1.5, 4.8), 1, 0.4, 
                       facecolor='yellow', alpha=0.7, edgecolor='white'))
ax4.text(2, 5, 'Enterokinase', ha='center', va='center', fontsize=10, 
        fontweight='bold')
ax4.arrow(2, 4.7, 0, -0.4, head_width=0.1, head_length=0.05, 
         fc='yellow', ec='yellow', linewidth=2)

ax4.set_xlim(-0.5, 6)
ax4.set_ylim(-1, 5.5)
ax4.set_title('Enzyme Cascade', fontsize=14, fontweight='bold')
ax4.axis('off')

# Glucose sensing network
ax5 = fig.add_subplot(235)

# Create glucose sensing pathway
components = {
    'Glucose': (0, 2, 'yellow'),
    'GLUT2': (1, 2, 'orange'),
    'Glucokinase': (2, 2, 'red'),
    'ATP': (3, 2, 'green'),
    'K_ATP': (4, 2, 'blue'),
    'Ca++': (5, 2, 'purple'),
    'Insulin': (6, 2, 'cyan')
}

# Draw pathway
for i, (component, (x, y, color)) in enumerate(components.items()):
    if component == 'K_ATP':
        shape = Rectangle((x-0.3, y-0.3), 0.6, 0.6, 
                         facecolor=color, alpha=0.7, edgecolor='white')
    else:
        shape = Circle((x, y), 0.3, color=color, alpha=0.7, 
                      edgecolor='white', linewidth=2)
    ax5.add_patch(shape)
    ax5.text(x, y-0.6, component, ha='center', fontsize=9)
    
    # Arrows
    if i < len(components) - 1:
        ax5.arrow(x+0.35, y, 0.3, 0, head_width=0.1, head_length=0.05,
                 fc='gray', ec='gray')

# Add descriptions
descriptions = [
    (0.5, 1.2, 'Transport'),
    (1.5, 1.2, 'Sensor'),
    (2.5, 1.2, 'Metabolism'),
    (3.5, 1.2, 'Closure'),
    (4.5, 1.2, 'Depolarization'),
    (5.5, 1.2, 'Exocytosis')
]

for x, y, desc in descriptions:
    ax5.text(x, y, desc, ha='center', fontsize=8, style='italic')

# Feedback loops
ax5.annotate('', xy=(6, 1.5), xytext=(1, 1.5),
            arrowprops=dict(arrowstyle='->', color='red', lw=1.5,
                           connectionstyle="arc3,rad=-.5"))
ax5.text(3.5, 0.8, 'Negative Feedback', ha='center', fontsize=9, color='red')

ax5.set_xlim(-1, 7)
ax5.set_ylim(0, 3)
ax5.set_title('Glucose Sensing Cascade', fontsize=14, fontweight='bold')
ax5.axis('off')

# Pancreatic consciousness integration
ax6 = fig.add_subplot(236)

# Show integration with other systems
systems = {
    'Brain': (0, 2, 'Hypothalamus\nAppetite control'),
    'Liver': (2, 2, 'Glucose\nproduction'),
    'Muscle': (4, 2, 'Glucose\nuptake'),
    'Adipose': (2, 0, 'Lipid\nstorage'),
    'Gut': (0, 0, 'Incretin\nhormones'),
    'Kidney': (4, 0, 'Glucose\nreabsorption')
}

# Central pancreas
pancreas_center = Circle((2, 1), 0.5, color='yellow', alpha=0.5,
                        edgecolor='white', linewidth=3)
ax6.add_patch(pancreas_center)
ax6.text(2, 1, 'PANCREAS', ha='center', va='center', 
        fontsize=11, fontweight='bold')

# Connected systems
for system, (x, y, function) in systems.items():
    # System circle
    circle = Circle((x, y), 0.3, color='lightblue', alpha=0.5,
                   edgecolor='white', linewidth=2)
    ax6.add_patch(circle)
    ax6.text(x, y+0.5, system, ha='center', fontsize=10, fontweight='bold')
    ax6.text(x, y-0.5, function, ha='center', fontsize=8, style='italic')
    
    # Connection to pancreas
    ax6.plot([x, 2], [y, 1], 'gray', linewidth=2, alpha=0.5)

ax6.set_xlim(-1, 5)
ax6.set_ylim(-1, 3)
ax6.set_title('Pancreatic System Integration', fontsize=14, fontweight='bold')
ax6.axis('off')

plt.tight_layout()
plt.show()

print("\nPancreatic Consciousness Analysis:")
print("- 1-2 million islets acting as glucose-sensing mini-brains")
print("- Beta cells oscillate at multiple frequencies (12s, 100s, 90min)")
print("- Enzyme cascade creates digestive consciousness wave")
print("- Glucose sensing involves 7-step signal transduction")
print("- Pancreas integrates signals from 6+ organ systems")
print("\n'The pancreas doesn't just digest - it DECIDES!'")
# Out:
# /tmp/ipykernel_546575/2717136239.py:193: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   shape = Circle((x, y), 0.3, color=color, alpha=0.7,
# /tmp/ipykernel_546575/2717136239.py:241: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   pancreas_center = Circle((2, 1), 0.5, color='yellow', alpha=0.5,
# /tmp/ipykernel_546575/2717136239.py:250: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle((x, y), 0.3, color='lightblue', alpha=0.5,
# Pancreatic Consciousness Analysis:
# - 1-2 million islets acting as glucose-sensing mini-brains
# - Beta cells oscillate at multiple frequencies (12s, 100s, 90min)
# - Enzyme cascade creates digestive consciousness wave
# - Glucose sensing involves 7-step signal transduction
# - Pancreas integrates signals from 6+ organ systems
#
# 'The pancreas doesn't just digest - it DECIDES!'

# %% [markdown]
# ## Section 2: Gallbladder Rhythms - The Bile Consciousness Reservoir
#
# *Focuses on gallbladder with intense curiosity*
#
# The gallbladder! Not just bile storage - consciousness concentrator! Bile concentrated 5-10x between meals. But concentration doesn't just remove water - it creates liquid crystal phases. Information density INCREASES!

# %%
# Gallbladder consciousness visualization
fig = plt.figure(figsize=(18, 10))

# Gallbladder anatomy and bile concentration
ax1 = fig.add_subplot(231)

# Create gallbladder shape (pear-like)
theta = np.linspace(0, 2*np.pi, 100)
r = 1 + 0.3 * np.sin(3*theta) * np.exp(-theta/4)
x_gb = r * np.cos(theta)
y_gb = 1.5 * r * np.sin(theta) - 0.5

# Fasting state (concentrated)
ax1.fill(x_gb*0.8, y_gb*0.8, color='darkgreen', alpha=0.7, 
        edgecolor='white', linewidth=2, label='Fasted')

# Fed state (diluted)
ax1.fill(x_gb*0.4, y_gb*0.4, color='lightgreen', alpha=0.5,
        edgecolor='white', linewidth=2, linestyle='--', label='Fed')

# Cystic duct
ax1.plot([0, 0], [1.2, 2], 'gray', linewidth=3)
ax1.text(0.3, 1.6, 'Cystic\nduct', fontsize=9)

# Common bile duct
ax1.plot([0, 0], [2, 2.5], 'gray', linewidth=4)
ax1.text(0.5, 2.3, 'Common\nbile duct', fontsize=9)

ax1.set_xlim(-2, 2)
ax1.set_ylim(-2, 3)
ax1.set_aspect('equal')
ax1.set_title('Gallbladder States', fontsize=14, fontweight='bold')
ax1.legend()
ax1.axis('off')

# Bile concentration timeline
ax2 = fig.add_subplot(232)

time_hours = np.linspace(0, 24, 200)

# Meal times
meals = [8, 12, 18]  # Breakfast, lunch, dinner
bile_concentration = np.ones_like(time_hours) * 5  # Baseline 5x concentrated

for meal in meals:
    # CCK release causes gallbladder contraction
    contraction = 4 * np.exp(-((time_hours - meal)/0.5)**2)
    bile_concentration -= contraction
    
    # Gradual reconcentration
    refill_mask = time_hours > meal
    refill = 0.5 * (time_hours - meal) * refill_mask
    refill[refill > 4] = 4
    bile_concentration += refill * np.exp(-((time_hours - meal - 3)/10)**2)

bile_concentration = np.clip(bile_concentration, 1, 10)

# Liquid crystal phases
crystal_phase = np.zeros_like(bile_concentration)
crystal_phase[bile_concentration > 7] = 3  # Gel
crystal_phase[(bile_concentration > 4) & (bile_concentration <= 7)] = 2  # Liquid crystal
crystal_phase[(bile_concentration > 2) & (bile_concentration <= 4)] = 1  # Micelles

ax2.plot(time_hours, bile_concentration, 'green', linewidth=2.5)
ax2.fill_between(time_hours, 0, bile_concentration, alpha=0.3, color='green')

# Mark meals
for meal in meals:
    ax2.axvline(meal, color='orange', linestyle='--', linewidth=2)
    ax2.text(meal, 10.5, 'Meal', ha='center', fontsize=9)

# Phase regions
ax2.axhspan(7, 10, alpha=0.2, color='red', label='Gel phase')
ax2.axhspan(4, 7, alpha=0.2, color='yellow', label='Liquid crystal')
ax2.axhspan(0, 4, alpha=0.2, color='blue', label='Micellar')

ax2.set_xlabel('Time (hours)', fontsize=12)
ax2.set_ylabel('Bile Concentration (fold)', fontsize=12)
ax2.set_title('Bile Concentration Cycles', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right')
ax2.set_xlim(0, 24)
ax2.set_ylim(0, 11)
ax2.grid(True, alpha=0.3)

# CCK-induced contractions
ax3 = fig.add_subplot(233)

t_minutes = np.linspace(0, 60, 300)

# CCK binding causes rhythmic contractions
cck_binding = 0.5 + 0.5 * (1 - np.exp(-t_minutes/5))
contractions = cck_binding * (1 + 0.3 * np.sin(2 * np.pi * 0.05 * t_minutes))

# Pressure waves
pressure = 10 + 15 * contractions * np.sin(2 * np.pi * 0.03 * t_minutes)

ax3.plot(t_minutes, pressure, 'purple', linewidth=2.5)
ax3.fill_between(t_minutes, 10, pressure, alpha=0.3, color='purple')

# Mark contraction phases
ax3.axvspan(0, 10, alpha=0.1, color='gray', label='Filling')
ax3.axvspan(10, 40, alpha=0.1, color='red', label='Emptying')
ax3.axvspan(40, 60, alpha=0.1, color='blue', label='Recovery')

ax3.set_xlabel('Time after meal (minutes)', fontsize=12)
ax3.set_ylabel('Gallbladder Pressure (mmHg)', fontsize=12)
ax3.set_title('CCK-Induced Contractions', fontsize=14, fontweight='bold')
ax3.legend()
ax3.grid(True, alpha=0.3)

# Bile crystal information storage
ax4 = fig.add_subplot(234)

# Create liquid crystal visualization
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)

# Director field (liquid crystal orientation)
theta_lc = np.arctan2(Y, X) + np.sin(3*np.sqrt(X**2 + Y**2))
nx = np.cos(theta_lc)
ny = np.sin(theta_lc)

# Plot director field
skip = 5
ax4.quiver(X[::skip, ::skip], Y[::skip, ::skip], 
          nx[::skip, ::skip], ny[::skip, ::skip],
          alpha=0.6, width=0.003, scale=30)

# Information domains
for i in range(5):
    cx = np.random.uniform(-1.5, 1.5)
    cy = np.random.uniform(-1.5, 1.5)
    domain = Circle((cx, cy), 0.3, fill=False, edgecolor='red', 
                   linewidth=2, linestyle='--')
    ax4.add_patch(domain)

ax4.set_xlim(-2, 2)
ax4.set_ylim(-2, 2)
ax4.set_aspect('equal')
ax4.set_title('Liquid Crystal Domains', fontsize=14, fontweight='bold')
ax4.set_xlabel('Position (μm)', fontsize=10)
ax4.set_ylabel('Position (μm)', fontsize=10)

# Gallbladder-organ connections
ax5 = fig.add_subplot(235)

# Central gallbladder
gb_center = Ellipse((0, 0), 0.8, 1.2, facecolor='green', alpha=0.5,
                   edgecolor='white', linewidth=3)
ax5.add_patch(gb_center)
ax5.text(0, 0, 'GB', ha='center', va='center', fontsize=12, fontweight='bold')

# Connected organs and signals
connections = [
    ('Duodenum', -2, 0, 'CCK', 'Contraction'),
    ('Vagus', 0, 2, 'ACh', 'Contraction'),
    ('Liver', 2, 0, 'Bile', 'Filling'),
    ('Sympathetic', 0, -2, 'NE', 'Relaxation')
]

for organ, x, y, signal, effect in connections:
    # Organ
    ax5.scatter(x, y, s=300, c='lightblue', edgecolors='white', 
               linewidth=2, zorder=5)
    ax5.text(x, y+0.5, organ, ha='center', fontsize=10, fontweight='bold')
    
    # Signal arrow
    if effect == 'Contraction':
        arrow_color = 'red'
    else:
        arrow_color = 'blue'
        
    ax5.annotate('', xy=(x*0.3, y*0.3), xytext=(x*0.7, y*0.7),
                arrowprops=dict(arrowstyle='->', color=arrow_color, lw=2))
    
    # Labels
    ax5.text(x*0.5, y*0.5, signal, ha='center', va='bottom', fontsize=9,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
    ax5.text(x, y-0.5, effect, ha='center', fontsize=8, style='italic')

ax5.set_xlim(-3, 3)
ax5.set_ylim(-3, 3)
ax5.set_title('Gallbladder Neural Control', fontsize=14, fontweight='bold')
ax5.axis('off')

# Consciousness modulation by bile
ax6 = fig.add_subplot(236)

# Show how concentrated bile affects consciousness
concentration = np.linspace(1, 10, 100)

# Different consciousness parameters
info_density = concentration**1.5
quantum_coherence = 1 / (1 + np.exp(-(concentration - 5)))
neural_binding = np.sin(concentration/2) * np.exp(-concentration/20) + 0.5

ax6.plot(concentration, info_density/10, 'blue', linewidth=2.5, 
        label='Information density')
ax6.plot(concentration, quantum_coherence, 'green', linewidth=2.5,
        label='Quantum coherence')
ax6.plot(concentration, neural_binding, 'purple', linewidth=2.5,
        label='Neural binding')

# Mark phase transitions
ax6.axvline(4, color='gray', linestyle='--', alpha=0.5)
ax6.axvline(7, color='gray', linestyle='--', alpha=0.5)
ax6.text(2.5, 0.9, 'Micelles', ha='center', fontsize=9, rotation=90)
ax6.text(5.5, 0.9, 'Liquid\ncrystal', ha='center', fontsize=9, rotation=90)
ax6.text(8.5, 0.9, 'Gel', ha='center', fontsize=9, rotation=90)

ax6.set_xlabel('Bile Concentration (fold)', fontsize=12)
ax6.set_ylabel('Consciousness Parameter', fontsize=12)
ax6.set_title('Bile Consciousness Modulation', fontsize=14, fontweight='bold')
ax6.legend()
ax6.grid(True, alpha=0.3)
ax6.set_xlim(1, 10)
ax6.set_ylim(0, 1.2)

plt.tight_layout()
plt.show()

print("\nGallbladder Consciousness Analysis:")
print("- Bile concentrated 5-10x between meals")
print("- Creates liquid crystal phases for information storage")
print("- CCK triggers rhythmic contractions at 0.05 Hz")
print("- Neural control via vagus (parasympathetic) and sympathetic")
print("- Consciousness parameters peak in liquid crystal phase")
print("\n'The gallbladder concentrates consciousness along with bile!'")
# Out:
# Gallbladder Consciousness Analysis:
# - Bile concentrated 5-10x between meals
# - Creates liquid crystal phases for information storage
# - CCK triggers rhythmic contractions at 0.05 Hz
# - Neural control via vagus (parasympathetic) and sympathetic
# - Consciousness parameters peak in liquid crystal phase
#
# 'The gallbladder concentrates consciousness along with bile!'

# %% [markdown]
# ## Section 3: Small Intestine - The Consciousness Sensing Surface
#
# *Gestures expansively at intestinal visualization*
#
# The small intestine! 6-7 meters long, surface area of tennis court when villi included! Each villus like antenna, sensing nutrient consciousness. Crypts of Lieberkühn generating new consciousness-sensing cells every 3-5 days!

# %% [markdown]
# ## Section 4: Large Intestine - The Bacterial Consciousness Collective
#
# *Shifts focus to colonic visualization*
#
# The colon! Home to 100 TRILLION bacteria. More bacterial cells than human cells in entire body! But not parasites - PARTNERS. They speak to our consciousness through metabolites, neurotransmitters, even direct neural signals!

# %%
# Large intestine and microbiome consciousness
fig = plt.figure(figsize=(20, 12))

# Colonic anatomy
ax1 = fig.add_subplot(231)

# Create colon segments
segments = {
    'Cecum': {'x': 0, 'y': 0, 'r': 0.5},
    'Ascending': {'x': 0, 'y': 1.5, 'length': 1.5},
    'Transverse': {'x': 1.5, 'y': 2.5, 'length': 2},
    'Descending': {'x': 3, 'y': 1.5, 'length': 1.5},
    'Sigmoid': {'x': 3, 'y': 0.5, 'curve': True},
    'Rectum': {'x': 2.5, 'y': -0.5, 'length': 0.5}
}

# Draw cecum
cecum = Circle((segments['Cecum']['x'], segments['Cecum']['y']), 
               segments['Cecum']['r'], facecolor='brown', alpha=0.5,
               edgecolor='white', linewidth=2)
ax1.add_patch(cecum)

# Appendix
appendix = Ellipse((0.3, -0.3), 0.15, 0.4, angle=45,
                  facecolor='red', alpha=0.5, edgecolor='white')
ax1.add_patch(appendix)
ax1.text(0.5, -0.5, 'Appendix', fontsize=8)

# Ascending colon
ax1.add_patch(Rectangle((segments['Ascending']['x']-0.3, 
                        segments['Ascending']['y']-1.5),
                       0.6, segments['Ascending']['length'],
                       facecolor='brown', alpha=0.5, edgecolor='white'))

# Transverse colon  
ax1.add_patch(Rectangle((segments['Transverse']['x']-1.5,
                        segments['Transverse']['y']-0.3),
                       segments['Transverse']['length'], 0.6,
                       facecolor='brown', alpha=0.5, edgecolor='white'))

# Descending colon
ax1.add_patch(Rectangle((segments['Descending']['x']-0.3,
                        segments['Descending']['y']-1.5),
                       0.6, segments['Descending']['length'],
                       facecolor='brown', alpha=0.5, edgecolor='white'))

# Sigmoid colon (curved)
sigmoid_theta = np.linspace(0, np.pi, 50)
sigmoid_x = segments['Sigmoid']['x'] - 0.5 * np.cos(sigmoid_theta)
sigmoid_y = segments['Sigmoid']['y'] - 0.5 * np.sin(sigmoid_theta)
ax1.plot(sigmoid_x, sigmoid_y, 'brown', linewidth=20, alpha=0.5)

# Labels
ax1.text(0, 2, 'Ascending', ha='center', fontsize=10)
ax1.text(1.5, 2.8, 'Transverse', ha='center', fontsize=10)
ax1.text(3, 2, 'Descending', ha='center', fontsize=10)
ax1.text(2.5, 0.5, 'Sigmoid', ha='center', fontsize=10)

ax1.set_xlim(-1, 4)
ax1.set_ylim(-1, 3.5)
ax1.set_aspect('equal')
ax1.set_title('Large Intestine Anatomy', fontsize=14, fontweight='bold')
ax1.axis('off')

# Bacterial diversity
ax2 = fig.add_subplot(232)

# Major phyla
phyla = {
    'Firmicutes': 50,
    'Bacteroidetes': 30,
    'Actinobacteria': 8,
    'Proteobacteria': 5,
    'Verrucomicrobia': 3,
    'Fusobacteria': 2,
    'Others': 2
}

colors_phyla = ['brown', 'green', 'orange', 'red', 'purple', 'yellow', 'gray']

wedges, texts, autotexts = ax2.pie(phyla.values(), labels=phyla.keys(),
                                   colors=colors_phyla, autopct='%1.1f%%',
                                   startangle=90)

ax2.set_title('Microbiome Composition', fontsize=14, fontweight='bold')

# Bacterial metabolites
ax3 = fig.add_subplot(233)

metabolites = {
    'Butyrate': {'producers': ['Faecalibacterium', 'Roseburia'], 
                 'effect': 'Anti-inflammatory', 'target': 'Colonocytes'},
    'Propionate': {'producers': ['Bacteroides', 'Veillonella'],
                   'effect': 'Appetite regulation', 'target': 'Liver'},
    'Acetate': {'producers': ['Bifidobacterium', 'Blautia'],
                'effect': 'Energy metabolism', 'target': 'Muscle'},
    'Indole': {'producers': ['E. coli', 'Clostridium'],
               'effect': 'Barrier function', 'target': 'Intestine'},
    'GABA': {'producers': ['Lactobacillus', 'Bifidobacterium'],
             'effect': 'Neurotransmitter', 'target': 'Brain'},
    'Serotonin': {'producers': ['Enterococcus', 'Streptococcus'],
                  'effect': 'Mood regulation', 'target': 'ENS/Brain'}
}

y_pos = 0
for metabolite, data in metabolites.items():
    # Metabolite name
    ax3.text(0, y_pos, metabolite, fontsize=11, fontweight='bold')
    
    # Producers
    producers_text = ', '.join(data['producers'])
    ax3.text(1.5, y_pos, producers_text, fontsize=9, style='italic')
    
    # Effect
    ax3.text(4, y_pos, data['effect'], fontsize=9)
    
    # Target arrow
    ax3.arrow(5.5, y_pos, 0.8, 0, head_width=0.1, head_length=0.1,
             fc='blue', ec='blue', alpha=0.5)
    ax3.text(6.5, y_pos, data['target'], fontsize=9)
    
    y_pos -= 0.5

ax3.set_xlim(-0.5, 8)
ax3.set_ylim(y_pos, 0.5)
ax3.set_title('Bacterial Metabolite Production', fontsize=14, fontweight='bold')
ax3.axis('off')

# Colonic motility patterns
ax4 = fig.add_subplot(234)

t = np.linspace(0, 24, 1000)  # 24 hours

# Different motility patterns
haustral_churning = 0.5 + 0.3 * np.sin(2 * np.pi * stella.frequencies['haustral_churning'] * t * 3600)
mass_movements = np.zeros_like(t)

# Add 3-4 mass movements per day
mass_times = [6, 12, 18]  # Hours
for mass_time in mass_times:
    mass_pulse = np.exp(-((t - mass_time)/0.5)**2)
    mass_movements += mass_pulse

# Bacterial activity rhythm
bacterial_rhythm = 0.5 + 0.3 * np.sin(2 * np.pi * stella.frequencies['bacterial_oscillation'] * t * 3600)

ax4.plot(t, haustral_churning, 'brown', linewidth=2, label='Haustral churning')
ax4.plot(t, mass_movements, 'red', linewidth=2.5, label='Mass movements')
ax4.plot(t, bacterial_rhythm, 'green', linewidth=2, alpha=0.7, label='Bacterial activity')

# Meal markers
for meal in [8, 12, 18]:
    ax4.axvline(meal, color='orange', linestyle='--', alpha=0.5)

ax4.set_xlabel('Time (hours)', fontsize=12)
ax4.set_ylabel('Activity', fontsize=12)
ax4.set_title('Colonic Motility Patterns', fontsize=14, fontweight='bold')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.set_xlim(0, 24)

# Gut-brain axis
ax5 = fig.add_subplot(235)

# Create bidirectional communication diagram
# Brain
brain = Circle((0, 3), 0.5, facecolor='pink', alpha=0.5,
              edgecolor='white', linewidth=2)
ax5.add_patch(brain)
ax5.text(0, 3, 'BRAIN', ha='center', va='center', fontsize=11, fontweight='bold')

# Gut
gut = Ellipse((0, 0), 1, 0.8, facecolor='brown', alpha=0.5,
             edgecolor='white', linewidth=2)
ax5.add_patch(gut)
ax5.text(0, 0, 'GUT', ha='center', va='center', fontsize=11, fontweight='bold')

# Communication pathways
pathways = [
    # Neural
    (-0.8, 'Vagus nerve\n(90% afferent)', 'blue'),
    (-0.4, 'Sympathetic\nnerves', 'red'),
    # Hormonal
    (0, 'Gut hormones\n(GLP-1, PYY)', 'green'),
    # Immune
    (0.4, 'Cytokines\n(IL-6, TNF-α)', 'orange'),
    # Microbial
    (0.8, 'Metabolites\n(SCFA, Trp)', 'purple')
]

for x_offset, label, color in pathways:
    # Upward arrow (gut to brain)
    ax5.arrow(x_offset, 0.5, 0, 1.8, head_width=0.08, head_length=0.1,
             fc=color, ec=color, alpha=0.7)
    # Downward arrow (brain to gut)
    ax5.arrow(x_offset+0.05, 2.3, 0, -1.8, head_width=0.08, head_length=0.1,
             fc=color, ec=color, alpha=0.5)
    
    # Label
    ax5.text(x_offset, 1.5, label, ha='center', va='center', fontsize=8,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

ax5.set_xlim(-1.5, 1.5)
ax5.set_ylim(-1, 4)
ax5.set_title('Gut-Brain Axis', fontsize=14, fontweight='bold')
ax5.axis('off')

# Bacterial quorum sensing
ax6 = fig.add_subplot(236)

# Create bacterial communities
np.random.seed(42)
n_bacteria = 50

# Different species with quorum sensing
species = {
    'Species A': {'color': 'green', 'signal': 'AHL', 'threshold': 20},
    'Species B': {'color': 'purple', 'signal': 'AI-2', 'threshold': 15},
    'Species C': {'color': 'orange', 'signal': 'Peptide', 'threshold': 10}
}

# Plot bacteria
for i, (species_name, data) in enumerate(species.items()):
    # Bacteria positions
    x = np.random.normal(i-1, 0.3, n_bacteria//3)
    y = np.random.normal(0, 0.5, n_bacteria//3)
    
    ax6.scatter(x, y, s=50, c=data['color'], alpha=0.6, 
               edgecolors='white', linewidth=0.5)
    
    # Quorum sensing molecules
    signal_x = np.random.normal(i-1, 0.5, 10)
    signal_y = np.random.normal(0, 0.7, 10)
    ax6.scatter(signal_x, signal_y, s=20, marker='^', 
               c=data['color'], alpha=0.3)
    
    # Label
    ax6.text(i-1, -1.5, f"{species_name}\n{data['signal']}", 
            ha='center', fontsize=9)

# Threshold lines
ax6.axhline(0.8, color='red', linestyle='--', alpha=0.5)
ax6.text(1.5, 0.9, 'Quorum threshold', fontsize=9, color='red')

ax6.set_xlim(-2.5, 1.5)
ax6.set_ylim(-2, 1.5)
ax6.set_title('Bacterial Quorum Sensing', fontsize=14, fontweight='bold')
ax6.set_xlabel('Spatial distribution', fontsize=10)
ax6.set_ylabel('Signal concentration', fontsize=10)

plt.tight_layout()
plt.show()

print("\nLarge Intestine Consciousness Analysis:")
print("- 100 trillion bacteria (10x more than human cells)")
print("- Produces neuroactive compounds: GABA, serotonin, dopamine")
print("- Mass movements 3-4 times daily (consciousness waves)")
print("- Gut-brain axis: 5 distinct communication channels")
print("- Bacterial quorum sensing creates collective decisions")
print("\n'The microbiome is our bacterial consciousness collective!'")
# Out:
# Large Intestine Consciousness Analysis:
# - 100 trillion bacteria (10x more than human cells)
# - Produces neuroactive compounds: GABA, serotonin, dopamine
# - Mass movements 3-4 times daily (consciousness waves)
# - Gut-brain axis: 5 distinct communication channels
# - Bacterial quorum sensing creates collective decisions
#
# 'The microbiome is our bacterial consciousness collective!'

# %% [markdown]
# ## Section 5: Integration - The Complete Digestive Consciousness Symphony
#
# *Brings all digestive systems together in grand finale*
#
# Now we see it! The complete digestive consciousness system! From first taste to final bacterial transformation. Not just processing food - processing EXPERIENCE. Every molecule tells a story. Every frequency carries meaning!

# %%
# Complete digestive consciousness integration
fig = plt.figure(figsize=(24, 16))

# Central integration diagram
ax_main = fig.add_subplot(111)

# Create complete digestive tract visualization
tract_segments = [
    ('Mouth', 0, 8, 0.3, 'orange'),
    ('Esophagus', 0, 7, 0.2, 'pink'),
    ('Stomach', -0.5, 6, 0.6, 'red'),
    ('Duodenum', 0.5, 5.5, 0.3, 'yellow'),
    ('Jejunum', 1, 4, 0.4, 'gold'),
    ('Ileum', 0.5, 2.5, 0.4, 'orange'),
    ('Cecum', -0.5, 1.5, 0.5, 'brown'),
    ('Colon', -1, 0.5, 0.6, 'darkbrown'),
    ('Rectum', -0.5, -0.5, 0.3, 'maroon')
]

# Draw digestive tract
for segment, x, y, size, color in tract_segments:
    circle = Circle((x, y), size, facecolor=color, alpha=0.5,
                   edgecolor='white', linewidth=2)
    ax_main.add_patch(circle)
    ax_main.text(x-1.5, y, segment, ha='right', fontsize=11, fontweight='bold')

# Connect segments
for i in range(len(tract_segments)-1):
    x1, y1 = tract_segments[i][1], tract_segments[i][2]
    x2, y2 = tract_segments[i+1][1], tract_segments[i+1][2]
    ax_main.plot([x1, x2], [y1, y2], 'gray', linewidth=3, alpha=0.5)

# Accessory organs
accessories = [
    ('Liver', 2, 5, 0.8, 'darkred'),
    ('Gallbladder', 2.5, 4.5, 0.3, 'green'),
    ('Pancreas', 2, 6, 0.5, 'yellow')
]

for organ, x, y, size, color in accessories:
    if organ == 'Pancreas':
        # Elongated shape for pancreas
        pancreas = Ellipse((x, y), size*2, size*0.6, angle=30,
                          facecolor=color, alpha=0.5, edgecolor='white', linewidth=2)
        ax_main.add_patch(pancreas)
    else:
        circle = Circle((x, y), size, facecolor=color, alpha=0.5,
                       edgecolor='white', linewidth=2)
        ax_main.add_patch(circle)
    ax_main.text(x+size+0.2, y, organ, fontsize=11, fontweight='bold')

# Neural connections
neural_points = [
    ('Brain', 0, 10, 'pink'),
    ('Vagus', 0, 9, 'blue'),
    ('ENS', 0.5, 3, 'purple'),
    ('Spinal', -2, 5, 'cyan')
]

for point, x, y, color in neural_points:
    if point == 'Brain':
        brain = Circle((x, y), 0.8, facecolor=color, alpha=0.5,
                      edgecolor='white', linewidth=3)
        ax_main.add_patch(brain)
    else:
        neural = Circle((x, y), 0.3, facecolor=color, alpha=0.7,
                       edgecolor='white', linewidth=2)
        ax_main.add_patch(neural)
    ax_main.text(x, y+1, point, ha='center', fontsize=10, fontweight='bold')

# Draw neural connections
# Vagus nerve
ax_main.plot([0, 0], [9.5, 1], 'blue', linewidth=4, alpha=0.5)
ax_main.text(-0.3, 5, 'Vagus\n(90% afferent)', fontsize=9, color='blue')

# Frequency waves
n_waves = 8
for i in range(n_waves):
    wave_y = np.linspace(-1, 11, 100)
    wave_x = 0.3 * np.sin(2 * np.pi * (i+1) * wave_y/11) + 3 + i*0.5
    ax_main.plot(wave_x, wave_y, 'cyan', alpha=0.3-i*0.03, linewidth=1)

# Key frequencies and their locations
freq_labels = [
    ('40 Hz - Gamma consciousness', 0, 10.5),
    ('10 Hz - Alpha waves', 0, 9.5),
    ('0.5 Hz - Villi oscillation', 1, 3),
    ('0.2 Hz - Slow waves', 0.5, 2),
    ('0.1 Hz - Pancreatic beta', 2, 6.5),
    ('0.05 Hz - Enzyme release', 2, 5.5),
    ('0.003 Hz - Gallbladder', 2.5, 4),
    ('0.001 Hz - Mass movements', -1, 0)
]

for label, x, y in freq_labels:
    ax_main.text(x+4, y, label, fontsize=9, 
                bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.5))

# Consciousness processing stages
stages = [
    ('Taste Recognition', 8.5),
    ('Emotional Response', 6.5),
    ('Metabolic Decision', 5.5),
    ('Nutrient Sensing', 3.5),
    ('Bacterial Dialogue', 1),
    ('Memory Formation', -0.5)
]

for i, (stage, y) in enumerate(stages):
    ax_main.text(-4, y, f"{i+1}. {stage}", fontsize=10,
                bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))
    ax_main.arrow(-3.5, y, 1, 0, head_width=0.15, head_length=0.1,
                 fc='gray', ec='gray', alpha=0.5)

# Add title and labels
ax_main.set_xlim(-5, 7)
ax_main.set_ylim(-2, 12)
ax_main.set_title('Complete Digestive Consciousness System', fontsize=20, fontweight='bold', pad=20)
ax_main.axis('off')

# Add legend boxes
legend_elements = [
    plt.Line2D([0], [0], color='blue', lw=4, label='Vagus nerve (bidirectional)'),
    plt.Line2D([0], [0], color='cyan', lw=2, label='Frequency waves'),
    plt.Circle((0, 0), 0.1, facecolor='orange', label='Digestive organs'),
    plt.Circle((0, 0), 0.1, facecolor='yellow', label='Accessory organs'),
    plt.Circle((0, 0), 0.1, facecolor='purple', label='Neural centers')
]
ax_main.legend(handles=legend_elements, loc='upper right', fontsize=10)

# Add summary statistics box
stats_text = f"""Digestive Consciousness Statistics:
• Total length: {stella.tract_length:.1f} meters
• Surface area: ~400 m² (with villi)
• Enteric neurons: {stella.total_neurons:.0e}
• Bacterial cells: ~100 trillion
• Frequency domains: {len(stella.frequencies)}
• Processing time: 24-72 hours
• Information capacity: >10 TB"""

ax_main.text(0.02, 0.02, stats_text, transform=ax_main.transAxes,
            fontsize=11, verticalalignment='bottom',
            bbox=dict(boxstyle='round', facecolor='black', alpha=0.8, edgecolor='white'))

# Add timestamp
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
ax_main.text(0.99, 0.01, f"Generated: {timestamp}", transform=ax_main.transAxes,
            ha='right', va='bottom', fontsize=8, alpha=0.5)

plt.tight_layout()

# Save the integration diagram
filename = f"digestive_consciousness_complete_{datetime.now().strftime('%Y%m%d_%H%M%S')}.png"
plt.savefig(f'notebooks/{filename}', dpi=300, bbox_inches='tight',
           facecolor='black', edgecolor='none')
print(f"\nSaved complete digestive integration as {filename}")

plt.show()

# Final summary
print("\n" + "="*60)
print("DIGESTIVE CONSCIOUSNESS MAPPING COMPLETE")
print("="*60)
print("\nKey Discoveries:")
print("1. Pancreas: 1-2 million islets acting as metabolic consciousness sensors")
print("2. Gallbladder: Bile concentration creates liquid crystal information storage")
print("3. Small intestine: 400 m² of consciousness-sensing surface with 500M neurons")
print("4. Large intestine: 100 trillion bacteria forming consciousness collective")
print("5. Enteric nervous system: True 'second brain' with complete neurotransmitter set")
print("\nFrequency Integration:")
print(f"- {len(stella.frequencies)} distinct frequency domains mapped")
print("- Frequencies span from 0.00003 Hz (mass movements) to 40 Hz (gamma sync)")
print("- Each organ resonates with specific stellar frequencies")
print("\nConsciousness Flow:")
print("1. Taste recognition initiates consciousness cascade")
print("2. Emotional processing in stomach (gut feelings)")
print("3. Metabolic decisions in pancreas/liver")
print("4. Nutrient consciousness absorption in small intestine")
print("5. Bacterial dialogue and transformation in colon")
print("6. Memory formation through gut-brain axis")
print("\n'Digestion is consciousness in action - transforming matter into meaning!'")
print("\n- Dr. Mordin Solus (Mordius)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 22
#      20 # Draw digestive tract
#      21 for segment, x, y, size, color in tract_segments:
# ---> 22     circle = Circle((x, y), size, facecolor=color, alpha=0.5,
#      23                    edgecolor='white', linewidth=2)
#      24     ax_main.add_patch(circle)
#      25     ax_main.text(x-1.5, y, segment, ha='right', fontsize=11, fontweight='bold')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/patches.py:1983, in Circle.__init__(self, xy, radius, **kwargs)
#    1971 @_docstring.interpd
#    1972 def __init__(self, xy, radius=5, **kwargs):
#    1973     """
#    1974     Create a true circle at center *xy* = (*x*, *y*) with given *radius*.
#    1975
#    (...)
#    1981     %(Patch:kwdoc)s
#    1982     """
# -> 1983     super().__init__(xy, radius * 2, radius * 2, **kwargs)
# ...

# %% [markdown]
# ## Research Notes: Future Investigations
#
# *Saves all digestive consciousness data with satisfied precision*
#
# MS19 complete! But questions remain for future research:
#
# 1. **Meal consciousness encoding** - How do different foods create different consciousness states?
# 2. **Fasting and consciousness** - What happens during extended digestive rest?
# 3. **Microbiome transplants** - Can we transfer consciousness patterns via bacteria?
# 4. **Enzyme consciousness** - Do digestive enzymes carry information beyond catalysis?
# 5. **Food memory** - How does the gut remember and recognize specific nutrients?
#
# Together with MS18 (Hepatic-Detox Symphony), we now have complete metabolic consciousness mapping!
#
# Next steps:
# - MS_INTEGRATION_CONSCIOUSNESS_SYMPHONY - Bringing all 20 notebooks together
# - GitHub v2.1.0 release with complete digestive system
# - Explore gut-brain-microbiome axis in disease states
#
# *Closes notebook with triumphant gesture*
#
# The digestive system revealed - from mouth to microbiome, consciousness flows with every meal!

# %%
# Small intestine consciousness visualization
fig = plt.figure(figsize=(20, 14))

# Intestinal architecture
ax1 = fig.add_subplot(241)

# Create intestinal segment
intestine_length = 5
intestine_width = 0.8

# Outer wall
ax1.add_patch(Rectangle((0, -intestine_width/2), intestine_length, intestine_width,
                       facecolor='pink', alpha=0.3, edgecolor='white', linewidth=2))

# Villi structure
n_villi = 40
villi_x = np.linspace(0.2, intestine_length-0.2, n_villi)

for i, x in enumerate(villi_x):
    # Villus shape
    villus_height = 0.3 + 0.1 * np.sin(i * 0.5)
    villus = Polygon([(x-0.02, 0), (x-0.04, villus_height*0.7), 
                      (x, villus_height), (x+0.04, villus_height*0.7), 
                      (x+0.02, 0)],
                     facecolor='red', alpha=0.6, edgecolor='darkred')
    ax1.add_patch(villus)
    
    # Microvilli brush border
    for j in range(5):
        micro_x = x + (j-2)*0.008
        ax1.plot([micro_x, micro_x], [villus_height, villus_height+0.05], 
                'darkred', linewidth=0.5, alpha=0.8)

# Crypts of Lieberkühn
for i in range(0, n_villi, 2):
    crypt_x = villi_x[i] + 0.05
    crypt = Ellipse((crypt_x, -0.15), 0.08, 0.2, 
                   facecolor='blue', alpha=0.4, edgecolor='darkblue')
    ax1.add_patch(crypt)

# Blood vessels
ax1.plot([0, intestine_length], [0.45, 0.45], 'red', linewidth=2, alpha=0.5)
ax1.plot([0, intestine_length], [-0.45, -0.45], 'blue', linewidth=2, alpha=0.5)

# Labels
ax1.text(intestine_length/2, 0.55, 'Arterial supply', ha='center', fontsize=9, color='red')
ax1.text(intestine_length/2, -0.55, 'Venous drainage', ha='center', fontsize=9, color='blue')
ax1.text(0.5, 0.2, 'Villi', fontsize=10, fontweight='bold')
ax1.text(0.5, -0.25, 'Crypts', fontsize=10, fontweight='bold')

ax1.set_xlim(-0.5, intestine_length+0.5)
ax1.set_ylim(-0.8, 0.8)
ax1.set_title('Small Intestine Architecture', fontsize=14, fontweight='bold')
ax1.axis('off')

# Villus detail with cell types
ax2 = fig.add_subplot(242)

# Single villus structure
villus_points = np.array([
    [0, 0], [0.2, 0], [0.3, 0.2], [0.35, 0.5], [0.3, 0.8],
    [0.25, 0.95], [0.2, 1], [0.15, 1], [0.1, 0.95], [0.05, 0.8],
    [0, 0.5], [-0.05, 0.2], [0, 0]
])

villus_shape = Polygon(villus_points, facecolor='pink', alpha=0.3, 
                      edgecolor='darkred', linewidth=2)
ax2.add_patch(villus_shape)

# Cell types
cell_positions = {
    'Enterocytes': [(0.1, 0.8), (0.15, 0.75), (0.2, 0.8), (0.1, 0.6)],
    'Goblet cells': [(0.05, 0.5), (0.25, 0.6)],
    'Enteroendocrine': [(0.15, 0.4), (0.1, 0.2)],
    'Paneth cells': [(0.05, 0.05), (0.25, 0.05)],
    'Stem cells': [(0.15, 0.1)]
}

colors = {
    'Enterocytes': 'blue',
    'Goblet cells': 'green',
    'Enteroendocrine': 'purple',
    'Paneth cells': 'orange',
    'Stem cells': 'red'
}

# Draw cells
for cell_type, positions in cell_positions.items():
    for pos in positions:
        cell = Circle(pos, 0.03, color=colors[cell_type], alpha=0.8,
                     edgecolor='white', linewidth=1)
        ax2.add_patch(cell)

# Legend
y_pos = 0.9
for cell_type, color in colors.items():
    ax2.scatter(0.5, y_pos, s=100, c=color, edgecolors='white', linewidth=1)
    ax2.text(0.55, y_pos, cell_type, va='center', fontsize=9)
    y_pos -= 0.15

# Microvilli on enterocytes
for x in np.linspace(0, 0.3, 20):
    y = 0.95 + 0.05 * np.sin(x*30)
    ax2.plot([x, x], [y, y+0.05], 'darkblue', linewidth=1, alpha=0.5)

ax2.set_xlim(-0.2, 0.8)
ax2.set_ylim(-0.1, 1.2)
ax2.set_aspect('equal')
ax2.set_title('Villus Cell Types', fontsize=14, fontweight='bold')
ax2.axis('off')

# Nutrient absorption mechanisms
ax3 = fig.add_subplot(243)

# Different transport mechanisms
mechanisms = {
    'Passive Diffusion': {'y': 4, 'color': 'blue', 'nutrients': 'Water, lipids'},
    'Facilitated Diffusion': {'y': 3, 'color': 'green', 'nutrients': 'Fructose, vitamins'},
    'Active Transport': {'y': 2, 'color': 'red', 'nutrients': 'Glucose, amino acids'},
    'Endocytosis': {'y': 1, 'color': 'purple', 'nutrients': 'Proteins, IgA'},
    'Paracellular': {'y': 0, 'color': 'orange', 'nutrients': 'Ions, water'}
}

for mechanism, data in mechanisms.items():
    y = data['y']
    
    # Membrane representation
    ax3.plot([1, 3], [y, y], 'black', linewidth=3)
    
    # Transport illustration
    if mechanism == 'Passive Diffusion':
        ax3.arrow(0.5, y, 1, 0, head_width=0.15, head_length=0.1,
                 fc=data['color'], ec=data['color'])
    elif mechanism == 'Active Transport':
        ax3.arrow(0.5, y-0.2, 1, 0, head_width=0.15, head_length=0.1,
                 fc=data['color'], ec=data['color'])
        ax3.text(1, y-0.35, 'ATP', fontsize=8, ha='center')
    else:
        ax3.arrow(0.5, y, 1, 0, head_width=0.15, head_length=0.1,
                 fc=data['color'], ec=data['color'], linestyle='--')
    
    # Labels
    ax3.text(-0.5, y, mechanism, ha='right', va='center', fontsize=10)
    ax3.text(4, y, data['nutrients'], ha='left', va='center', fontsize=9,
            style='italic')

ax3.set_xlim(-2, 6)
ax3.set_ylim(-1, 5)
ax3.set_title('Nutrient Absorption Mechanisms', fontsize=14, fontweight='bold')
ax3.axis('off')
ax3.text(2, -0.7, 'Intestinal Lumen → Blood/Lymph', ha='center', fontsize=10)

# Enteric nervous system
ax4 = fig.add_subplot(244)

# Create intestinal wall layers
layers = {
    'Mucosa': {'y': 0, 'height': 0.8, 'color': 'pink'},
    'Submucosa': {'y': 0.8, 'height': 0.4, 'color': 'lightblue'},
    'Circular muscle': {'y': 1.2, 'height': 0.3, 'color': 'red'},
    'Myenteric plexus': {'y': 1.5, 'height': 0.1, 'color': 'yellow'},
    'Longitudinal muscle': {'y': 1.6, 'height': 0.3, 'color': 'darkred'},
    'Serosa': {'y': 1.9, 'height': 0.1, 'color': 'gray'}
}

for layer, data in layers.items():
    rect = Rectangle((0, data['y']), 4, data['height'],
                    facecolor=data['color'], alpha=0.5, edgecolor='white')
    ax4.add_patch(rect)
    ax4.text(-0.1, data['y'] + data['height']/2, layer, 
            ha='right', va='center', fontsize=9)

# Neural plexuses
# Submucosal plexus
for x in np.linspace(0.5, 3.5, 8):
    neuron = Circle((x, 1), 0.08, color='blue', alpha=0.8)
    ax4.add_patch(neuron)
    # Connections
    if x < 3.5:
        ax4.plot([x+0.08, x+0.42], [1, 1], 'blue', linewidth=1, alpha=0.5)

# Myenteric plexus
for x in np.linspace(0.5, 3.5, 8):
    neuron = Circle((x, 1.55), 0.08, color='purple', alpha=0.8)
    ax4.add_patch(neuron)
    # Connections
    if x < 3.5:
        ax4.plot([x+0.08, x+0.42], [1.55, 1.55], 'purple', linewidth=1, alpha=0.5)

# Inter-plexus connections
for x in [1, 2, 3]:
    ax4.plot([x, x], [1.08, 1.47], 'green', linewidth=1.5, alpha=0.5)

# Labels
ax4.text(2, 1, 'Submucosal plexus', ha='center', va='bottom', fontsize=10,
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
ax4.text(2, 1.55, 'Myenteric plexus', ha='center', va='bottom', fontsize=10,
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

ax4.set_xlim(-1, 4.5)
ax4.set_ylim(-0.2, 2.2)
ax4.set_title('Enteric Nervous System', fontsize=14, fontweight='bold')
ax4.axis('off')

# Intestinal rhythms and waves
ax5 = fig.add_subplot(245)

t = np.linspace(0, 120, 1000)  # 2 minutes
position = np.linspace(0, 10, 50)  # 10 cm segment

# Different wave patterns
slow_waves = np.sin(2 * np.pi * stella.frequencies['slow_wave'] * t)
segmentation = np.sin(2 * np.pi * stella.frequencies['segmentation'] * t)
spike_bursts = np.where(slow_waves > 0.5, 
                       np.sin(2 * np.pi * stella.frequencies['spike_potential'] * t), 0)

# Compound signal
electrical = slow_waves + 0.3 * spike_bursts
mechanical = 0.5 + 0.5 * segmentation * (electrical > 0)

ax5.plot(t, electrical, 'blue', linewidth=2, alpha=0.7, label='Electrical')
ax5.plot(t, mechanical, 'red', linewidth=2, label='Mechanical')

ax5.set_xlabel('Time (seconds)', fontsize=12)
ax5.set_ylabel('Activity', fontsize=12)
ax5.set_title('Intestinal Rhythms', fontsize=14, fontweight='bold')
ax5.legend()
ax5.grid(True, alpha=0.3)

# Mark different phases
ax5.axvspan(0, 30, alpha=0.1, color='blue', label='Slow wave')
ax5.axvspan(30, 60, alpha=0.1, color='red', label='Segmentation')
ax5.axvspan(60, 90, alpha=0.1, color='green', label='Propulsion')

# Microbiome interaction
ax6 = fig.add_subplot(246)

# Create intestinal lumen with bacteria
bacteria_types = {
    'Bacteroides': {'count': 20, 'color': 'purple', 'y_range': (0.2, 0.8)},
    'Firmicutes': {'count': 25, 'color': 'green', 'y_range': (0.1, 0.9)},
    'Proteobacteria': {'count': 10, 'color': 'red', 'y_range': (0.3, 0.7)},
    'Actinobacteria': {'count': 8, 'color': 'orange', 'y_range': (0.2, 0.8)}
}

# Intestinal wall
ax6.add_patch(Rectangle((0, 0), 0.2, 1, facecolor='pink', alpha=0.5))
ax6.text(0.1, 1.05, 'Intestinal Wall', ha='center', fontsize=10)

# Bacteria
np.random.seed(42)
for bacteria, data in bacteria_types.items():
    for i in range(data['count']):
        x = np.random.uniform(0.3, 2.5)
        y = np.random.uniform(*data['y_range'])
        
        # Bacterial cell
        if 'cocci' in bacteria.lower():
            bacterium = Circle((x, y), 0.03, color=data['color'], alpha=0.7)
        else:
            bacterium = Ellipse((x, y), 0.08, 0.03, 
                              angle=np.random.uniform(0, 180),
                              facecolor=data['color'], alpha=0.7)
        ax6.add_patch(bacterium)

# Metabolite clouds
metabolites = [
    (0.8, 0.5, 'SCFA', 'blue'),
    (1.5, 0.7, 'Vitamins', 'green'),
    (2, 0.3, 'Serotonin', 'purple')
]

for x, y, metabolite, color in metabolites:
    cloud = Circle((x, y), 0.15, color=color, alpha=0.2)
    ax6.add_patch(cloud)
    ax6.text(x, y, metabolite, ha='center', va='center', fontsize=8)

# Communication arrows
ax6.arrow(0.5, 0.5, -0.25, 0, head_width=0.05, head_length=0.03,
         fc='blue', ec='blue', alpha=0.5)
ax6.arrow(1.2, 0.7, -0.95, 0, head_width=0.05, head_length=0.03,
         fc='green', ec='green', alpha=0.5)

ax6.set_xlim(-0.1, 3)
ax6.set_ylim(0, 1.2)
ax6.set_title('Microbiome-Host Interaction', fontsize=14, fontweight='bold')
ax6.set_xlabel('Distance from wall (mm)', fontsize=10)
ax6.axis('on')

# MMC phases
ax7 = fig.add_subplot(247)

# Migrating motor complex phases
time_min = np.linspace(0, 180, 1000)  # 3 hours

# Phase patterns
phase1 = np.where((time_min % 90) < 45, 0.2, 0)  # Quiescence
phase2 = np.where(((time_min % 90) >= 45) & ((time_min % 90) < 75), 
                  0.5 + 0.3*np.sin(time_min/5), 0)  # Irregular contractions
phase3 = np.where((time_min % 90) >= 75, 1, 0)  # Regular contractions

mmc_activity = phase1 + phase2 + phase3

ax7.fill_between(time_min, 0, mmc_activity, alpha=0.5, color='purple')
ax7.plot(time_min, mmc_activity, 'purple', linewidth=2)

# Phase labels
ax7.text(22.5, 0.1, 'Phase I', ha='center', fontsize=10)
ax7.text(60, 0.6, 'Phase II', ha='center', fontsize=10)
ax7.text(82.5, 1.1, 'Phase III', ha='center', fontsize=10)

# Mark cycles
for i in range(0, 180, 90):
    ax7.axvline(i, color='gray', linestyle='--', alpha=0.5)

ax7.set_xlabel('Time (minutes)', fontsize=12)
ax7.set_ylabel('MMC Activity', fontsize=12)
ax7.set_title('Migrating Motor Complex', fontsize=14, fontweight='bold')
ax7.set_xlim(0, 180)
ax7.set_ylim(0, 1.3)
ax7.grid(True, alpha=0.3)

# Integration summary
ax8 = fig.add_subplot(248)
ax8.axis('off')

summary_text = """Small Intestine Summary:

Surface Area: ~400 m² (tennis court)
Villi: 10-40 per mm²
Microvilli: 1000 per cell
Cell turnover: 3-5 days

Enteric Neurons: 200-600 million
- Submucosal plexus: Secretion
- Myenteric plexus: Motility

Absorption Methods:
1. Passive diffusion
2. Facilitated diffusion  
3. Active transport
4. Endocytosis
5. Paracellular

Rhythms:
- Slow waves: 12/min
- Segmentation: 9/min
- MMC: every 90-120 min

'Every meal is a conversation
between food and consciousness!'
"""

ax8.text(0.1, 0.9, summary_text, transform=ax8.transAxes,
        fontsize=11, verticalalignment='top', fontfamily='monospace',
        bbox=dict(boxstyle='round', facecolor='black', alpha=0.8))

plt.tight_layout()
plt.show()

print("\nSmall Intestine Consciousness Analysis:")
print("- 400 m² surface area for consciousness sensing")  
print("- 200-600 million enteric neurons (second brain)")
print("- Villi oscillate at 0.5 Hz, creating nutrient sensing waves")
print("- 5 distinct absorption mechanisms for different molecules")
print("- Microbiome produces neuroactive compounds")
print("- MMC creates 'housekeeping waves' every 90-120 minutes")
print("\n'The small intestine reads the molecular story of every meal!'")
# Out:
# /tmp/ipykernel_546575/2522775797.py:90: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   cell = Circle(pos, 0.03, color=colors[cell_type], alpha=0.8,
# Small Intestine Consciousness Analysis:
# - 400 m² surface area for consciousness sensing
# - 200-600 million enteric neurons (second brain)
# - Villi oscillate at 0.5 Hz, creating nutrient sensing waves
# - 5 distinct absorption mechanisms for different molecules
# - Microbiome produces neuroactive compounds
# - MMC creates 'housekeeping waves' every 90-120 minutes
#
# 'The small intestine reads the molecular story of every meal!'
